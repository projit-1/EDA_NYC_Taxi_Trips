# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno

# %%
df = pd.read_parquet("yellow_tripdata_2025-01.parquet")

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.60         1.0                  N           229           237
# 1           0.50         1.0                  N           236           237
# 2           0.60         1.0                  N           141           141
# 3           0.52         1.0                  N           244           244
# 4           0.66         1.0                  N           244           116
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.tail()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 3475221         2  2025-01-31 23:01:48   2025-01-31 23:16:29              NaN
# 3475222         2  2025-01-31 23:50:29   2025-02-01 00:17:27              NaN
# 3475223         2  2025-01-31 23:26:59   2025-01-31 23:43:01              NaN
# 3475224         2  2025-01-31 23:14:34   2025-01-31 23:34:52              NaN
# 3475225         2  2025-01-31 23:56:42   2025-02-01 00:07:27              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 3475221           3.35         NaN               None            79
# 3475222           8.73         NaN               None           161
# 3475223           2.64         NaN               None           144
# 3475224           3.16         NaN               None           142
# 3475225           2.29         NaN               None           237
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
df.sample(5)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2835217         2  2025-01-31 01:24:42   2025-01-31 01:36:44              1.0
# 1402229         2  2025-01-16 12:26:09   2025-01-16 12:31:18              1.0
# 2351319         2  2025-01-25 23:54:51   2025-01-26 00:09:38              2.0
# 1339372         2  2025-01-15 18:02:40   2025-01-15 18:10:17              1.0
# 2882037         2  2025-01-31 15:50:35   2025-01-31 16:17:08              2.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 2835217           2.65         1.0                  N           137
# 1402229           0.94         1.0                  N           141
# 2351319           1.85         1.0                  N            50
# 1339372           1.18         1.0                  N           211
# 2882037           6.11         1.0                  N           261
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
df.shape
# Out:
# (3475226, 20)

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee',
#        'cbd_congestion_fee'],
#       dtype='object')

# %%
df.dtypes
# Out:
# VendorID                          int32
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int32
# DOLocationID                      int32
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# Airport_fee                     float64
# cbd_congestion_fee              float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3475226 entries, 0 to 3475225
# Data columns (total 20 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
#  19  cbd_congestion_fee     float64
# ...

# %%
df.describe()
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  3.475226e+06                     3475226                     3475226
# mean   1.785428e+00  2025-01-17 11:02:55.910964  2025-01-17 11:17:56.997901
# min    1.000000e+00         2024-12-31 20:47:55         2024-12-18 07:52:40
# 25%    2.000000e+00         2025-01-10 07:59:01  2025-01-10 08:15:29.500000
# 50%    2.000000e+00         2025-01-17 15:41:33         2025-01-17 15:59:34
# 75%    2.000000e+00         2025-01-24 19:34:06         2025-01-24 19:48:31
# max    7.000000e+00         2025-02-01 00:00:44         2025-02-01 23:44:11
# std    4.263282e-01                         NaN                         NaN
#
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count     2.935077e+06   3.475226e+06  2.935077e+06  3.475226e+06
# mean      1.297859e+00   5.855126e+00  2.482535e+00  1.651916e+02
# min       0.000000e+00   0.000000e+00  1.000000e+00  1.000000e+00
# ...

# %%
df.isnull().sum()
# Out:
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count          540149
# trip_distance                 0
# RatecodeID               540149
# store_and_fwd_flag       540149
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# congestion_surcharge     540149
# Airport_fee              540149
# cbd_congestion_fee            0
# dtype: int64

# %%
(df.isnull().mean()*100).sort_values(ascending=False)
# Out:
# Airport_fee              15.542845
# passenger_count          15.542845
# congestion_surcharge     15.542845
# RatecodeID               15.542845
# store_and_fwd_flag       15.542845
# VendorID                  0.000000
# mta_tax                   0.000000
# total_amount              0.000000
# improvement_surcharge     0.000000
# tolls_amount              0.000000
# tip_amount                0.000000
# fare_amount               0.000000
# extra                     0.000000
# tpep_pickup_datetime      0.000000
# payment_type              0.000000
# DOLocationID              0.000000
# PULocationID              0.000000
# trip_distance             0.000000
# tpep_dropoff_datetime     0.000000
# cbd_congestion_fee        0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['passenger_count'] = (
    df['passenger_count']
    .fillna(df['passenger_count'].median())
)

# %%
df['RatecodeID'] = (
    df['RatecodeID']
    .fillna(df['RatecodeID'].mode()[0])
)

# %%
df['store_and_fwd_flag'] = (
    df['store_and_fwd_flag']
    .fillna('Unknown')
)

# %%
df['Airport_fee'] = (
    df['Airport_fee']
    .fillna(0)
)

# %%
df['congestion_surcharge'] = (
    df['congestion_surcharge']
    .fillna(0)
)

# %%
df.describe(include="all")
# Out:
#             VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count   3.475226e+06                     3475226                     3475226
# unique           NaN                         NaN                         NaN
# top              NaN                         NaN                         NaN
# freq             NaN                         NaN                         NaN
# mean    1.785428e+00  2025-01-17 11:02:55.910964  2025-01-17 11:17:56.997901
# min     1.000000e+00         2024-12-31 20:47:55         2024-12-18 07:52:40
# 25%     2.000000e+00         2025-01-10 07:59:01  2025-01-10 08:15:29.500000
# 50%     2.000000e+00         2025-01-17 15:41:33         2025-01-17 15:59:34
# 75%     2.000000e+00         2025-01-24 19:34:06         2025-01-24 19:48:31
# max     7.000000e+00         2025-02-01 00:00:44         2025-02-01 23:44:11
# std     4.263282e-01                         NaN                         NaN
#
# ...

# %%
(df.isnull().mean()*100).sort_values(ascending=False)
# Out:
# Airport_fee              15.542845
# passenger_count          15.542845
# congestion_surcharge     15.542845
# RatecodeID               15.542845
# store_and_fwd_flag       15.542845
# VendorID                  0.000000
# mta_tax                   0.000000
# total_amount              0.000000
# improvement_surcharge     0.000000
# tolls_amount              0.000000
# tip_amount                0.000000
# fare_amount               0.000000
# extra                     0.000000
# tpep_pickup_datetime      0.000000
# payment_type              0.000000
# DOLocationID              0.000000
# PULocationID              0.000000
# trip_distance             0.000000
# tpep_dropoff_datetime     0.000000
# cbd_congestion_fee        0.000000
# dtype: float64

# %%
df[['passenger_count',
    'RatecodeID',
    'store_and_fwd_flag',
    'congestion_surcharge',
    'Airport_fee']].isna().sum()
# Out:
# passenger_count         0
# RatecodeID              0
# store_and_fwd_flag      0
# congestion_surcharge    0
# Airport_fee             0
# dtype: int64

# %%
msno.matrix(df)
plt.show()

# %%
df.memory_usage(deep=True)
# Out:
# Index                          132
# VendorID                  13900904
# tpep_pickup_datetime      27801808
# tpep_dropoff_datetime     27801808
# passenger_count           27801808
# trip_distance             27801808
# RatecodeID                27801808
# store_and_fwd_flag       204804002
# PULocationID              13900904
# DOLocationID              13900904
# payment_type              27801808
# fare_amount               27801808
# extra                     27801808
# mta_tax                   27801808
# tip_amount                27801808
# tolls_amount              27801808
# improvement_surcharge     27801808
# total_amount              27801808
# congestion_surcharge      27801808
# Airport_fee               27801808
# cbd_congestion_fee        27801808
# dtype: int64

# %%
df.memory_usage(deep=True).sum()/1024**2
# Out:
# 659.3091716766357

# %%
df.nunique()
# Out:
# VendorID                       4
# tpep_pickup_datetime     1672077
# tpep_dropoff_datetime    1671993
# passenger_count               10
# trip_distance               4545
# RatecodeID                     7
# store_and_fwd_flag             3
# PULocationID                 261
# DOLocationID                 260
# payment_type                   6
# fare_amount                11538
# extra                         77
# mta_tax                        9
# tip_amount                  4197
# tolls_amount                1234
# improvement_surcharge          4
# total_amount               21995
# congestion_surcharge           3
# Airport_fee                    7
# cbd_congestion_fee             3
# dtype: int64

# %%
df["passenger_count"].value_counts()
# Out:
# passenger_count
# 1.0    2862583
# 2.0     407761
# 3.0      91409
# 4.0      59009
# 0.0      24656
# 5.0      17786
# 6.0      12004
# 8.0         11
# 7.0          4
# 9.0          3
# Name: count, dtype: int64

# %%
df["payment_type"].value_counts()
# Out:
# payment_type
# 1    2444393
# 0     540149
# 2     390429
# 4      76481
# 3      23773
# 5          1
# Name: count, dtype: int64

# %%
df["tpep_pickup_datetime"] = pd.to_datetime(df["tpep_pickup_datetime"])

# %%
df["tpep_dropoff_datetime"] = pd.to_datetime(df["tpep_dropoff_datetime"])

# %%
df["pickup_year"] = df["tpep_pickup_datetime"].dt.year

# %%
df["pickup_month"] = df["tpep_pickup_datetime"].dt.month

# %%
df["weekday"] = df["tpep_pickup_datetime"].dt.day_name()

# %%
df["pickup_hour"] = df["tpep_pickup_datetime"].dt.hour

# %%
df["is_weekend"] = df["weekday"].isin(["Saturday","Sunday"])

# %% [markdown]
# Trip Duration

# %%
df["trip_duration"] = (
    df["tpep_dropoff_datetime"]-
    df["tpep_pickup_datetime"]
).dt.total_seconds()/60

# %%
df["trip_duration"].describe()
# Out:
# count    3.475226e+06
# mean     1.501812e+01
# std      3.871358e+01
# min     -5.147232e+04
# 25%      7.283333e+00
# 50%      1.170000e+01
# 75%      1.833333e+01
# max      5.626317e+03
# Name: trip_duration, dtype: float64

# %% [markdown]
# Distance Analysis

# %%
df["trip_distance"].mean()
# Out:
# 5.855126178844196

# %%
df["trip_distance"].median()
# Out:
# 1.67

# %%
df["trip_distance"].max()
# Out:
# 276423.57

# %%
df["trip_distance"].min()
# Out:
# 0.0

# %%
df["trip_distance"].hist(bins=50)
plt.show()

# %% [markdown]
# Fare Analysis

# %%
df["fare_amount"].mean()
# Out:
# 17.081802760453577

# %%
df["fare_amount"].max()
# Out:
# 863372.12

# %%
df["fare_amount"].min()
# Out:
# -900.0

# %%
df["fare_amount"].hist(bins=50)
plt.show()

# %% [markdown]
# Total Amount Analysis

# %%
df["total_amount"].describe()
# Out:
# count    3.475226e+06
# mean     2.561129e+01
# std      4.636585e+02
# min     -9.010000e+02
# 25%      1.520000e+01
# 50%      1.995000e+01
# 75%      2.778000e+01
# max      8.633804e+05
# Name: total_amount, dtype: float64

# %%
df.nlargest(10,"tip_amount")
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1583318         2  2025-01-17 23:31:29   2025-01-18 00:12:47              1.0
# 2329131         2  2025-01-25 19:11:06   2025-01-25 19:11:10              1.0
# 2329130         2  2025-01-25 19:07:42   2025-01-25 19:08:50              1.0
# 286175          2  2025-01-04 15:41:54   2025-01-04 15:52:27              2.0
# 2315999         2  2025-01-25 18:24:51   2025-01-25 18:48:28              1.0
# 1184297         2  2025-01-14 11:17:31   2025-01-14 11:51:28              1.0
# 250630          2  2025-01-04 03:31:55   2025-01-04 03:51:06              2.0
# 413087          1  2025-01-06 00:16:24   2025-01-06 00:31:03              1.0
# 1527704         1  2025-01-17 14:36:05   2025-01-17 14:44:04              1.0
# 2666918         2  2025-01-29 15:17:36   2025-01-29 15:28:22              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# ...

# %% [markdown]
# Outlier Detection

# %%
Q1=df["trip_distance"].quantile(.25)
Q3=df["trip_distance"].quantile(.75)

IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR

outliers=df[(df["trip_distance"]<lower)|(df["trip_distance"]>upper)]

# %%
len(outliers)
# Out:
# 422436

# %% [markdown]
# Correlation

# %%
corr=df.corr(numeric_only=True)

corr
# Out:
#                        VendorID  passenger_count  trip_distance  RatecodeID  \
# VendorID               1.000000         0.109692       0.002373   -0.213959
# passenger_count        0.109692         1.000000       0.003609   -0.045093
# trip_distance          0.002373         0.003609       1.000000    0.022977
# RatecodeID            -0.213959        -0.045093       0.022977    1.000000
# PULocationID          -0.006897        -0.010883      -0.001946   -0.085538
# DOLocationID          -0.005810        -0.006710      -0.002209   -0.072965
# payment_type          -0.004040         0.028031      -0.006932   -0.043661
# fare_amount           -0.001574         0.001374       0.000182    0.004420
# extra                 -0.532195        -0.065410      -0.002486   -0.098577
# mta_tax               -0.064030        -0.030052       0.000327    0.006502
# tip_amount             0.012824         0.020370       0.000334   -0.094625
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
plt.imshow(corr)
plt.colorbar()
plt.xticks(range(len(corr.columns)),corr.columns,rotation=90)
plt.yticks(range(len(corr.columns)),corr.columns)
plt.show()

# %% [markdown]
# GroupBy Questions

# %%
df.groupby("payment_type")["fare_amount"].mean()
# Out:
# payment_type
# 0    14.587529
# 1    18.008540
# 2    16.603058
# 3     4.498180
# 4    11.434029
# 5     0.000000
# Name: fare_amount, dtype: float64

# %%
df.groupby("passenger_count")["trip_distance"].mean()
# Out:
# passenger_count
# 0.0     2.434000
# 1.0     3.094355
# 2.0     3.681512
# 3.0     3.483201
# 4.0     3.723703
# 5.0     2.938389
# 6.0     3.070723
# 7.0     0.005000
# 8.0     6.340000
# 9.0    14.863333
# Name: trip_distance, dtype: float64

# %%
df.groupby("VendorID")["total_amount"].sum()
# Out:
# VendorID
# 1    20183067.41
# 2    68780553.52
# 6       14985.67
# 7       26420.20
# Name: total_amount, dtype: float64

# %% [markdown]
# Sorting

# %%
df.nlargest(20,"total_amount")
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1780915         1  2025-01-20 12:07:18   2025-01-20 12:12:42              1.0
# 1404958         2  2025-01-16 12:23:14   2025-01-17 14:41:56              1.0
# 1832645         2  2025-01-21 05:17:57   2025-01-21 08:19:45              1.0
# 1346041         2  2025-01-15 19:14:42   2025-01-15 21:46:13              1.0
# 2358832         2  2025-01-26 00:04:04   2025-01-26 00:04:42              4.0
# 2358836         2  2025-01-26 00:22:47   2025-01-26 00:22:55              4.0
# 2358837         2  2025-01-26 00:24:25   2025-01-26 00:24:35              4.0
# 2358828         2  2025-01-26 00:00:56   2025-01-26 00:01:06              4.0
# 2353880         2  2025-01-25 23:56:58   2025-01-25 23:57:06              4.0
# 2353881         2  2025-01-25 23:58:50   2025-01-25 23:59:00              4.0
# 562143          2  2025-01-07 19:12:25   2025-01-07 19:14:04              1.0
# ...

# %%
df.nsmallest(20,"trip_distance")
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 92           1  2025-01-01 00:49:48   2025-01-01 00:49:48              1.0
# 204          2  2025-01-01 00:37:43   2025-01-01 00:37:53              1.0
# 358          2  2025-01-01 00:57:08   2025-01-01 00:57:16              3.0
# 505          1  2025-01-01 00:27:40   2025-01-01 00:59:30              1.0
# 619          2  2025-01-01 00:56:49   2025-01-01 00:56:54              4.0
# 706          1  2025-01-01 00:42:42   2025-01-01 00:42:44              0.0
# 1073         1  2025-01-01 00:43:22   2025-01-01 00:46:18              1.0
# 1345         2  2025-01-01 00:24:26   2025-01-01 00:24:34              4.0
# 1354         1  2025-01-01 00:14:57   2025-01-01 00:17:44              1.0
# 1496         2  2025-01-01 00:49:10   2025-01-01 00:49:14              4.0
# 1577         2  2025-01-01 00:16:07   2025-01-01 00:16:18              1.0
# ...

# %% [markdown]
# Filtering Questions

# %%
df[df["trip_distance"]>50]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 9215            1  2025-01-01 01:04:01   2025-01-01 03:33:22              2.0
# 10040           2  2025-01-01 01:05:24   2025-01-01 02:35:52              4.0
# 21389           2  2025-01-01 04:51:56   2025-01-01 07:03:12              1.0
# 23677           2  2025-01-01 06:02:52   2025-01-01 06:29:25              3.0
# 23791           2  2025-01-01 06:46:17   2025-01-01 07:53:15              1.0
# ...           ...                  ...                   ...              ...
# 3451364         1  2025-01-31 12:52:40   2025-01-31 13:02:57              NaN
# 3461154         2  2025-01-31 18:33:00   2025-01-31 18:53:00              NaN
# 3461434         2  2025-01-31 18:13:00   2025-01-31 18:21:00              NaN
# 3464668         2  2025-01-31 19:24:00   2025-01-31 19:35:00              NaN
# 3470452         2  2025-01-31 22:06:00   2025-01-31 22:16:00              NaN
#
# ...

# %%
df[df["fare_amount"]>100]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 823             2  2025-01-01 00:49:36   2025-01-01 02:11:46              4.0
# 902             2  2025-01-01 00:05:17   2025-01-01 00:54:59              2.0
# 918             1  2025-01-01 00:35:40   2025-01-01 01:11:54              3.0
# 1064            2  2025-01-01 00:08:31   2025-01-01 00:46:27              3.0
# 2221            2  2025-01-01 00:11:07   2025-01-01 00:53:06              1.0
# ...           ...                  ...                   ...              ...
# 3427645         2  2025-01-30 09:48:53   2025-01-30 10:45:54              NaN
# 3431497         2  2025-01-30 16:58:28   2025-01-30 17:57:48              NaN
# 3434759         2  2025-01-30 18:34:53   2025-01-30 19:35:55              NaN
# 3445082         2  2025-01-31 00:48:25   2025-01-31 02:52:26              NaN
# 3474055         2  2025-01-31 23:45:46   2025-02-01 00:36:00              NaN
#
# ...

# %%
df[df["tip_amount"]>50]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 8251            2  2025-01-01 01:25:26   2025-01-01 03:06:46              2.0
# 8627            2  2025-01-01 01:15:38   2025-01-01 02:20:10              4.0
# 10601           2  2025-01-01 01:09:12   2025-01-01 01:20:32              2.0
# 11672           2  2025-01-01 01:02:49   2025-01-01 01:08:46              1.0
# 12161           2  2025-01-01 02:01:05   2025-01-01 02:01:13              3.0
# ...           ...                  ...                   ...              ...
# 2914094         2  2025-01-31 20:54:40   2025-01-31 21:35:08              1.0
# 2923834         2  2025-01-31 21:18:07   2025-01-31 22:38:01              1.0
# 2927427         2  2025-01-31 22:16:29   2025-01-31 22:16:41              1.0
# 2931178         2  2025-01-31 23:25:51   2025-01-31 23:44:24              3.0
# 2932145         2  2025-01-31 23:27:39   2025-02-01 00:13:23              1.0
#
# ...

# %% [markdown]
# Peak Hours

# %%
df.groupby("pickup_hour").size()
# Out:
# pickup_hour
# 0      93417
# 1      64484
# 2      43929
# 3      28492
# 4      20033
# 5      22551
# 6      50026
# 7     102581
# 8     141305
# 9     142877
# 10    148316
# 11    160076
# 12    175432
# 13    186144
# 14    202289
# 15    213694
# 16    217051
# 17    253518
# 18    267951
# 19    221055
# 20    195001
# 21    205978
# 22    182214
# 23    136812
# dtype: int64

# %%
df.groupby("pickup_hour").size().plot(kind="bar")
plt.show()

# %% [markdown]
# Busiest Days

# %%
df.groupby("weekday").size()
# Out:
# weekday
# Friday       586863
# Monday       363772
# Saturday     476399
# Sunday       402594
# Thursday     614230
# Tuesday      453993
# Wednesday    577375
# dtype: int64

# %%
df["speed"]=(df["trip_distance"]/(df["trip_duration"]/60))

# %%
df["speed"].describe()
# Out:
# C:\Users\Projit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# count    3.474534e+06
# mean              inf
# std               NaN
# min     -6.436800e+04
# 25%      7.209809e+00
# 50%      9.519231e+00
# 75%      1.293839e+01
# max               inf
# Name: speed, dtype: float64

# %%
df["tip_percent"]=(
    df["tip_amount"]/df["fare_amount"]
)*100

# %%
df["tip_percent"].mean()
# Out:
# inf

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee',
#        'cbd_congestion_fee', 'trip_duration', 'speed', 'weekday',
#        'pickup_year', 'pickup_month', 'pickup_hour', 'is_weekend',
#        'tip_percent'],
#       dtype='object')

# %% [markdown]
# Revenue Analysis

# %%
df.groupby("weekday")["total_amount"].sum()
# Out:
# weekday
# Friday       14997333.87
# Monday       10584363.37
# Saturday     11363736.75
# Sunday       10190237.65
# Thursday     15863551.34
# Tuesday      11509452.78
# Wednesday    14496351.04
# Name: total_amount, dtype: float64

# %%
df.groupby("pickup_hour")["total_amount"].sum()
# Out:
# pickup_hour
# 0     2371982.77
# 1     1504284.38
# 2      973494.86
# 3      644218.37
# 4      560345.33
# 5      714342.51
# 6     1356957.11
# 7     2599478.08
# 8     3410758.24
# 9     3496775.88
# 10    3672648.45
# 11    3927036.05
# 12    5206860.59
# 13    4715047.41
# 14    5268653.56
# 15    5573589.56
# 16    6029906.12
# 17    6565618.13
# 18    6566541.38
# 19    5575551.51
# 20    4921270.10
# 21    5193015.73
# 22    4622288.63
# 23    3534362.05
# Name: total_amount, dtype: float64

# %% [markdown]
# Payment Type Distribution

# %%
df["payment_type"].value_counts(normalize=True)*100
# Out:
# payment_type
# 1    70.337670
# 0    15.542845
# 2    11.234636
# 4     2.200749
# 3     0.684071
# 5     0.000029
# Name: proportion, dtype: float64

# %% [markdown]
# Vendor Comparison

# %%
df["VendorID"].value_counts()
# Out:
# VendorID
# 2    2719860
# 1     753671
# 7       1206
# 6        489
# Name: count, dtype: int64

# %%
df.groupby("VendorID")["total_amount"].sum()
# Out:
# VendorID
# 1    20183067.41
# 2    68780553.52
# 6       14985.67
# 7       26420.20
# Name: total_amount, dtype: float64

# %%
df.groupby("VendorID")["fare_amount"].mean()
# Out:
# VendorID
# 1    18.447616
# 2    16.707627
# 6     2.968200
# 7    13.128607
# Name: fare_amount, dtype: float64

# %% [markdown]
# Location Analysis

# %%
df["PULocationID"].value_counts().head(20)
# Out:
# PULocationID
# 161    169977
# 237    163703
# 236    155647
# 132    146137
# 230    125829
# 186    119131
# 162    117930
# 142    110585
# 239     96614
# 163     95906
# 234     95896
# 170     95636
# 68      91241
# 138     89658
# 48      84137
# 141     81661
# 79      81576
# 249     77355
# 164     76066
# 140     75093
# Name: count, dtype: int64

# %%
df["DOLocationID"].value_counts().head(20)
# Out:
# DOLocationID
# 236    161376
# 237    149970
# 161    131258
# 230    108177
# 170    100060
# 142     98982
# 239     97559
# 162     93798
# 141     92675
# 68      89232
# 234     84669
# 163     84631
# 48      82722
# 238     78467
# 186     76338
# 79      76009
# 140     74165
# 263     73889
# 164     72594
# 229     71480
# Name: count, dtype: int64

# %% [markdown]
# Categorical Analysis

# %%
categorical=df.select_dtypes(include="object")

categorical.columns
# Out:
# Index(['store_and_fwd_flag', 'weekday'], dtype='object')

# %%
numeric=df.select_dtypes(include=np.number)

numeric.columns
# Out:
# Index(['VendorID', 'passenger_count', 'trip_distance', 'RatecodeID',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee',
#        'cbd_congestion_fee', 'trip_duration', 'speed', 'pickup_year',
#        'pickup_month', 'pickup_hour', 'tip_percent'],
#       dtype='object')

# %% [markdown]
# Boxplots

# %%
df.boxplot(column="fare_amount")
plt.show()

# %%
df["fare_amount"].quantile([0.25,0.5,0.75,0.90,0.95,0.99])
# Out:
# 0.25     8.60
# 0.50    12.11
# 0.75    19.50
# 0.90    34.98
# 0.95    52.00
# 0.99    72.30
# Name: fare_amount, dtype: float64
